# %% [markdown]
# Data with a consistent format is often described as "clean." As data scientists, not all data we encounter is clean; we often we need to prepare it in a process called **data cleaning**.

# %% [markdown]
# We going to work with data about the art in the Museum of Modern Art (MoMA). MoMA, a museum in New York City, has one of the largest collections of modern art in the world.

# %% [markdown]
# # Data dictionary for the MoMA
#
# * Title: The title of the artwork.
# * Artist: The name of the artist who created the artwork.
# * Nationality: The nationality of the artist.
# * BeginDate: The year in which the artist was born.
# * EndDate: The year in which the artist died.
# * Gender: The gender of the artist.
# * Date: The date that the artwork was created.
# * Department: The department inside MoMA to which the artwork belongs.

# %%
from csv import reader

opened_file = open("artworks.csv", encoding = "utf-8")
read_file = reader(opened_file)
moma = list(read_file)
moma_header = moma[0]
moma = moma[1:]

# %% [markdown]
# Often when we're cleaning data, we need to replace parts of strings so our data is consistent.
#
# For example, let's say we have the string "red is my favorite color", but we want to change it to "blue is my favorite color". To do that, we want to replace the "red" part of the string with "blue". When we want to refer to part of a string, we use the term substring.

# %% [markdown]
# * Parts of strings are called substrings.
# * We can use the str.replace() method to find and replace substrings.
# * str.replace() requires two arguments:
#   * old: The substring we want to find and replace.
#   * new: The substring we want to replace old with.
# * When we use str.replace(), we substitute the str for the variable name of the string we want to modify.
# * We need to use = to assign the modified string to a variable name.

# %%
# for learning purpose just consider below example of replacing value
age1 = "I am thirty-one years old" 

age2 = age1.replace("thirty-one", "thirty-two")

# %% [markdown]
# # Cleaning Nationality and Gender

# %%
for item in moma:
    nationality = item[2]
    nationality = nationality.replace("(", "")
    nationality = nationality.replace(")", "")
    item[2] = nationality
    
    gender = item[5]
    gender = gender.replace("(", "")
    gender = gender.replace(")", "")
    item[5] = gender

# %%
for item in moma:
    gender = item[5]
    gender = gender.title()
    if gender == "":
        gender = gender.replace("", "Gender Unknown/Other")
    item[5] = gender
    
    nationality = item[2]
    nationality = nationality.title()
    if nationality == "":
        nationality = nationality.replace("","Nationality Unknown")
    item[2] = nationality

# %% [markdown]
# # Cleaning begin and end dates

# %%
def clean_and_convert(date):
    if date != "":
        date = date.replace("(","")
        date = date.replace(")","")
        date = int(date)
    return date

# %%
for item in moma:
    birth_date = item[3]
    death_date = item[4]
    
    birth_date = clean_and_convert(birth_date)
    death_date = clean_and_convert(death_date)
    
    item[3] = birth_date
    item[4] = death_date

# %% [markdown]
# # Cleaning Date column

# %%
dates = []

for item in moma:
    date = item[6]
    dates.append(date)

# %%
test_data = ["1912", "1929", "1913-1923",
             "(1951)", "1994", "1934",
             "c. 1915", "1995", "c. 1912",
             "(1988)", "2002", "1957-1959",
             "c. 1955.", "c. 1970's", 
             "C. 1990-1999"]

bad_chars = ["(",")","c","C",".","s","'", " "]

# %%
def strip_characters(string):
    for char in bad_chars:
        string = string.replace(char,"")
    return string

# %%
for item in moma:
    date = item[6]
    date = strip_characters(date)
    item[6] = date

# %%
def process_date(string):
    if "-" in string:
        string = string.split("-")
        frst_indx = int(string[0])
        sec_indx = int(string[1])
        avg_value = round((frst_indx+sec_indx)/2)
        string = avg_value
    else:
        string = int(string)
    return string

# %%
for item in moma:
    date = item[6]
    date = strip_characters(date)
    date = process_date(date)
    item[6] = date

# %%
moma[0:3]
# Out:
# [['Dress MacLeod from Tartan Sets',
#   'Sarah Charlesworth',
#   'American',
#   1947,
#   2013,
#   'Female',
#   1986,
#   'Prints & Illustrated Books'],
#  ['Duplicate of plate from folio 11 verso (supplementary suite, plate 4) from ARDICIA',
#   'Pablo Palazuelo',
#   'Spanish',
#   1916,
#   2007,
#   'Male',
#   1978,
#   'Prints & Illustrated Books'],
#  ['Tailpiece (page 55) from SAGESSE',
#   'Maurice Denis',
#   'French',
#   1870,
#   1943,
#   'Male',
#   1900,
#   'Prints & Illustrated Books']]

# %% [markdown]
# # Preparing a CSV containing all of the data cleaning I performed, called artworks_clean.csv.

# %%
import csv
f = open("artworks_clean.csv", "w",newline= "",encoding="utf-8")
writer = csv.writer(f, delimiter = ",")
writer.writerow(moma_header)
for item in moma:
    print(item)
    writer.writerow(item)
# Out:
# ['Dress MacLeod from Tartan Sets', 'Sarah Charlesworth', 'American', 1947, 2013, 'Female', 1986, 'Prints & Illustrated Books']
# ['Duplicate of plate from folio 11 verso (supplementary suite, plate 4) from ARDICIA', 'Pablo Palazuelo', 'Spanish', 1916, 2007, 'Male', 1978, 'Prints & Illustrated Books']
# ['Tailpiece (page 55) from SAGESSE', 'Maurice Denis', 'French', 1870, 1943, 'Male', 1900, 'Prints & Illustrated Books']
# ['Headpiece (page 129) from LIVRET DE FOLASTRIES, À JANOT PARISIEN', 'Aristide Maillol', 'French', 1861, 1944, 'Male', 1934, 'Prints & Illustrated Books']
# ['97 rue du Bac', 'Eugène Atget', 'French', 1857, 1927, 'Male', 1903, 'Photography']
# ['Pictorial ornament (folio 11) from WOODCUTS', 'Antonio Frasconi', 'American', 1919, 2013, 'Male', 1957, 'Prints & Illustrated Books']
# ["Rue de l'Hôtel-de-Ville", 'Eugène Atget', 'French', 1857, 1927, 'Male', 1924, 'Photography']
# ['Los Angeles Airport', 'Garry Winogrand', 'American', 1928, 1984, 'Male', 1980, 'Photography']
# ['Why Defy from Disasters of Peace', 'Diane Victor', 'South African', 1964, '', 'Female', 2001, 'Prints & Illustrated Books']
# ['STILL WATER AND FISH', 'David Brown Milne', 'Canadian', 1882, 1953, 'Male', 1941, 'Prints & Illustrated Books']
# ['In-text plate (folio 11) from LA MÉTROMANIE', 'Jean Dubuffet', 'French', 1901, 1985, 'Male', 1950, 'Prints & Illustrated Books']
# ['Black Bathroom', 'Jim Dine', 'American', 1935, '', 'Male', 1963, 'Prints & Illustrated Books']
# ['In-text plate (page 108) from LYSISTRATA', 'František Kupka', 'Czech', 1871, 1957, 'Male', 1910, 'Prints & Illustrated Books']
# ['Transcendence. Designs for the Ballet', 'Franklin Chenault Watkins', 'American', 1894, 1972, 'Male', 1934, 'Drawings']
# ['Untitled', 'Christopher Wool', 'American', 1955, '', 'Male', 1997, 'Prints & Illustrated Books']
# ['Isadora Duncan', 'Abraham Walkowitz', 'American', 1878, 1965, 'Male', 1932, 'Drawings']
# ["L'Avenir de la Propriété", 'Pierre Alechinsky', 'Belgian', 1927, '', 'Male', 1972, 'Prints & Illustrated Books']
# ['Arundel Castle from Black Series I', 'Frank Stella', 'American', 1936, '', 'Male', 1967, 'Prints & Illustrated Books']
# ['Block fragments from the Samuel Freeman House, Los Angeles, CA', 'Frank Lloyd Wright', 'American', 1867, 1959, 'Male', 1924, 'Architecture & Design']
# ['Plate (folio 35) from ACORDE', 'Vicente Rojo', 'Spanish', 1932, '', 'Male', 1979, 'Prints & Illustrated Books']
# ['Wolf House, Gubin, Poland (Third floor plan)', 'Ludwig Mies van der Rohe', 'American', 1886, 1969, 'Male', 1926, 'Architecture & Design']
# ['SA. Sovremennaia Arkhitektura (CA. Contemporary Architecture), no. 5', 'Varvara Stepanova', 'Russian', 1894, 1958, 'Female', 1929, 'Prints & Illustrated Books']
# ['Untitled', 'Richard Serra', 'American', 1938, '', 'Male', 1972, 'Drawings']
# ['Research on the Origin', 'Robert Filliou', 'French', 1926, 1987, 'Male', 1974, 'Prints & Illustrated Books']
# ['Plate (folio 17) from KAFKA', 'Roger Chancel', 'French', 1898, 1976, 'Male', 1957, 'Prints & Illustrated Books']
# ['Tailpiece (page 35) from SAINTE MONIQUE', 'Pierre Bonnard', 'French', 1867, 1947, 'Male', 1925, 'Prints & Illustrated Books']
# ['Bowl', 'Jacqueline Poncelet', 'British', 1947, '', 'Female', 1974, 'Architecture & Design']
# ['Tailpiece (folio 42 verso) from LES AMOURS', 'Émile Bernard', 'French', 1868, 1941, 'Male', 1915, 'Prints & Illustrated Books']
# ['Tuileries (vase)', 'Eugène Atget', 'French', 1857, 1927, 'Male', 1912, 'Photography']
# ['Plate 23 (folio 25) from MALELADE', 'Georg Baselitz', 'German', 1938, '', 'Male', 1989, 'Prints & Illustrated Books']
# ['Duplicate of plate from folio 104 (supplementary suite, plate 95) from LA VILLE', 'Frans Masereel', 'Belgian', 1889, 1972, 'Male', 1925, 'Prints & Illustrated Books']
# ['Untitled', 'Unknown', 'Nationality Unknown', '', '', 'Gender Unknown/Other', 1925, 'Photography']
# ['Plate (folio 28) from Six Geometric Figures and All Their Combinations, Volume I', 'Sol LeWitt', 'American', 1928, 2007, 'Male', 1980, 'Prints & Illustrated Books']
# ['Chamber Music', 'James Tenney', 'American', 1934, 2006, 'Male', 1964, 'Prints & Illustrated Books']
# ['Plate (following folio V) from NOTES', 'Claes Oldenburg', 'American', 1929, '', 'Male', 1968, 'Prints & Illustrated Books']
# ['Chocolate Object (Schokolade-Objekt)', 'Dieter Roth', 'Swiss', 1930, 1998, 'Male', 1969, 'Prints & Illustrated Books']
# ["Mandry Ven'iamyna Tret'oho", 'Moisei Fradkin', 'Nationality Unknown', '', '', 'Male', 1934, 'Prints & Illustrated Books']
# ['Dust jacket front (duplicate of folder front) from 2 POEMAS', 'Antonio Frasconi', 'American', 1919, 2013, 'Male', 1953, 'Prints & Illustrated Books']
# ['Fun City from Fun City', 'Richard Lindner', 'American', 1901, 1978, 'Male', 1971, 'Prints & Illustrated Books']
# ['Angels from Witebsk', 'Wojciech Prazmowski', 'Polish', 1949, '', 'Male', 1988, 'Photography']
# ['Tailpiece (page 62) from FABLES', 'Thomas Bewick', 'British', 1753, 1828, 'Male', 1818, 'Prints & Illustrated Books']
# ['Untitled', 'Spencer Sweeney', 'American', 1973, '', 'Male', 2002, 'Drawings']
# ['Variety', 'Batiste Madalena', 'American', 1902, 1988, 'Male', 1926, 'Film']
# ['Stars and Disasters (Astres et Désastres)', 'Pierre Alechinsky', 'Belgian', 1927, '', 'Male', 1969, 'Prints & Illustrated Books']
# ['U.S. Embassy Building, Tokyo Project (Aerial perspective)', 'Frank Lloyd Wright', 'American', 1867, 1959, 'Male', 1914, 'Architecture & Design']
# ['Tuesday, Dec. 18, 1979', 'On Kawara', 'Japanese', 1933, '', 'Male', 1979, 'Painting & Sculpture']
# ['Bank by Andy Warhol. Gaudy Savings by RCA Color Scanner. Pretty as a Pigture, Huh?', 'Andy Warhol', 'American', 1928, 1987, 'Male', 1968, 'Architecture & Design']
# ['Pittsburgh, Pennsylvania', 'Lee Friedlander', 'American', 1934, '', 'Male', 1979, 'Photography']
# ['Double page plate (between pages 96 and 97) from UBU ROI', 'Joan Miró', 'Spanish', 1893, 1983, 'Male', 1966, 'Prints & Illustrated Books']
# ['Unity Temple, Oak Park, IL', 'Frank Lloyd Wright', 'American', 1867, 1959, 'Male', 1904, 'Architecture & Design']
# ['PORTRAITS DE CHOPIN', 'Marc Chagall', 'French', 1887, 1985, 'Male', 1949, 'Prints & Illustrated Books']
# ['The Razorback Bunch (Etching III)', 'Robert Rauschenberg', 'American', 1925, 2008, 'Male', 1981, 'Prints & Illustrated Books']
# ['Identity Transfer from Program One: Aspen Projects', 'Dennis Oppenheim', 'American', 1938, 2011, 'Male', 1970, 'Media and Performance Art']
# ['Lipstick (Ascending) on Caterpillar Track', 'Claes Oldenburg', 'American', 1929, '', 'Male', 1969, 'Prints & Illustrated Books']
# ['"1 PERSON/1 PLACE" from the portfolio DETAILS FROM THE EXCAVATION OF WOOSTER STREET', 'Richard Nonas', 'American', 1936, '', 'Male', 1972, 'Prints & Illustrated Books']
# ['Bagatelle', 'Eugène Atget', 'French', 1857, 1927, 'Male', 1924, 'Photography']
# ['The Barbie Doll Drawings #27', 'Adrian Piper', 'American', 1948, '', 'Female', 1967, 'Drawings']
# ['Gericke House, project, Berlin-Wannsee, Germany, Landscape model', 'Ludwig Mies van der Rohe', 'American', 1886, 1969, 'Male', 1932, 'Architecture & Design']
# ['Plate (page 209) from LES PETITES FLEURS', 'Émile Bernard', 'French', 1868, 1941, 'Male', 1928, 'Prints & Illustrated Books']
# ['Mechanical for Ticket for Fluxorchestra at Carnegie Hall, Carnegie Recital Hall, New York, September 25, 1965', 'George Maciunas', 'American', 1931, 1978, 'Male', 1965, 'Prints & Illustrated Books']
# ['Untitled', 'Louise Bourgeois', 'American', 1911, 2010, 'Female', 2003, 'Prints & Illustrated Books']
# ['Banco Pinto & Sotto Mayor, Oliveira de Azeméis, Portugal, Plan sketch', 'Álvaro Siza', 'Portuguese', 1933, '', 'Male', 1972, 'Architecture & Design']
# ['Overcast Dusk-Glassy Lake from Loon Lake: Eleven Drawings', 'Ellen Phelan', 'American', 1943, '', 'Female', 1983, 'Drawings']
# ['Golf Club Project, Krefeld, Germany', 'Ludwig Mies van der Rohe', 'American', 1886, 1969, 'Male', 1930, 'Architecture & Design']
# ['Stamp Box', 'Josef Hoffmann', 'Austrian', 1870, 1956, 'Male', 1946, 'Architecture & Design']
# ['Library, Villeurbanne, France, Interior rear elevation', 'Mario Botta', 'Swiss', 1943, '', 'Male', 1984, 'Architecture & Design']
# ['Studio II 1982 from Architecture Models 1980-2006 (Architektur Modelle 1980-2006)', 'Thomas Schütte', 'German', 1954, '', 'Male', 2006, 'Prints & Illustrated Books']
# ['Looking out from Black Hawks Cave, Wisconsin Dells', 'Henry Hamilton Bennett', 'American', 1843, 1908, 'Male', 1885, 'Photography']
# ['Apollon Musagete, design for Scenery', 'Pavel Tchelitchew', 'American', 1898, 1957, 'Male', 1942, 'Drawings']
# ['LA RUE DE LA PARCHEMINERIE APRÈS DÉMOLITION', 'Eugène Atget', 'French', 1857, 1927, 'Male', 1913, 'Photography']
# ['Scroll Down and Keep Scrolling', 'Fiona Banner', 'British', 1966, '', 'Female', 2015, 'Prints & Illustrated Books']
# ['"Untitled"', 'Felix Gonzalez-Torres', 'American', 1957, 1996, 'Male', 1987, 'Painting & Sculpture']
# ["Plate (page 89) from L'ÉVANGILE", 'Léo Marchutz', 'French', 1903, 1976, 'Male', 1948, 'Prints & Illustrated Books']
# ['Pleasures and Terrors of Levitation 50', 'Aaron Siskind', 'American', 1903, 1991, 'Male', 1965, 'Photography']
# ['Tailpiece (page 44) from FABLES', 'Thomas Bewick', 'British', 1753, 1828, 'Male', 1818, 'Prints & Illustrated Books']
# ['KOTSCHEI (plate, folio 7) from DEM FEUERVOGEL', 'Helmut A. P. Grieshaber', 'German', 1909, 1981, 'Male', 1961, 'Prints & Illustrated Books']
# ['RUES LANNEAU ET DES CARMES', 'Eugène Atget', 'French', 1857, 1927, 'Male', 1925, 'Photography']
# ['Plate (page 160) from RÉINCARNATIONS DU PÈRE UBU', 'Georges Rouault', 'French', 1871, 1958, 'Male', 1924, 'Prints & Illustrated Books']
# ['Landscape Triptych No. 1, State IV/IV', 'Fred Williams', 'Australian', 1927, 1982, 'Male', 1962, 'Prints & Illustrated Books']
# ['Mr. Bennett, Vermont', 'Paul Strand', 'American', 1890, 1976, 'Male', 1944, 'Photography']
# ['Portrait of Alice (frontispiece) from Alice in Wonderland', 'Marie Laurencin', 'French', 1883, 1956, 'Female', 1930, 'Prints & Illustrated Books']
# ['C.N.T. from the portfolio Color Guard Etcetera', 'Juan Hidalgo', 'Spanish', 1927, '', 'Male', 1991, 'Prints & Illustrated Books']
# ['Untitled. (portrait of man with dark glasses, Heino?)', 'Michael Schmidt', 'German', 1945, 2014, 'Male', 1992, 'Photography']
# ['Fortune', 'Kiki Smith', 'American', 1954, '', 'Female', 2008, 'Prints & Illustrated Books']
# ['Meeting Street, Charleston, South Carolina, August 3, 1975', 'Stephen Shore', 'American', 1947, '', 'Male', 1975, 'Photography']
# ['Cover for Old Stories (Les Vieilles Histoires)', 'Henri de Toulouse-Lautrec', 'French', 1864, 1901, 'Male', 1893, 'Prints & Illustrated Books']
# ['Untitled', 'Willem de Kooning', 'American', 1904, 1997, 'Male', 1966, 'Drawings']
# ['Double page plate (folios 14 and 15) from AMISH, Volume II', 'Stephen White', 'American', 1948, '', 'Male', 1968, 'Prints & Illustrated Books']
# ['Are You Rea #17', 'Robert Heinecken', 'American', 1931, 2006, 'Male', 1966, 'Photography']
# ['Headpiece (page 93) from PASSION', 'Georges Rouault', 'French', 1871, 1958, 'Male', 1934, 'Prints & Illustrated Books']
# ['Bar Tools', 'Studio Opi', 'Italian', 1955, '', 'Gender Unknown/Other', 1969, 'Architecture & Design']
# ['Multi-use Rocker Prototype', 'Frederick Kiesler', 'American', 1890, 1965, 'Male', 1942, 'Architecture & Design']
# ['Cascade Mountains', 'Lee Friedlander', 'American', 1934, '', 'Male', 1980, 'Photography']
# ['Japanese House in the Garden of the Museum of Modern Art', 'Ezra Stoller', 'American', 1915, 2004, 'Male', 1955, 'Architecture & Design']
# ['Neue Wache War Memorial Project, Berlin-Mitte, Germany', 'Ludwig Mies van der Rohe', 'American', 1886, 1969, 'Male', 1930, 'Architecture & Design']
# ['[History of Art Chart]', 'George Maciunas', 'American', 1931, 1978, 'Male', 1958, 'Prints & Illustrated Books']
# ['Bagatelle', 'Eugène Atget', 'French', 1857, 1927, 'Male', 1922, 'Photography']
# ['MR1002 Flower stand (Plan and detail sections)', 'Ludwig Mies van der Rohe', 'American', 1886, 1969, 'Male', 1934, 'Architecture & Design']
# ['FONTAINEBLEAU. COUR CHEVAL BLANC', 'Eugène Atget', 'French', 1857, 1927, 'Male', 1903, 'Photography']
# ['The Toe Tactic', 'Emily Hubley', 'American', 1958, '', 'Female', 2008, 'Film']
# ['Paper Piece, Festival of Misfits, ICA, London, October 23- November 8, 1962', 'Benjamin Patterson', 'American', 1934, 2016, 'Male', 1962, 'Prints & Illustrated Books']
# ['Taliesin Fellowship Complex, Midway Farm, Spring Green, WI (Plan and elevation of tower and weather vane)', 'Frank Lloyd Wright', 'American', 1867, 1959, 'Male', 1944, 'Architecture & Design']
# ["The Navy Needs You! Don't Read American History - Make It! U.S. Navy Recruiting Station", 'James Montgomery Flagg', 'American', 1877, 1960, 'Male', 1916, 'Architecture & Design']
# ['Untitled', 'Carey Maxon', 'American', 1978, '', 'Female', 2003, 'Drawings']
# ['Untitled from Program', 'Jorge Pardo', 'American', 1963, '', 'Male', 2012, 'Prints & Illustrated Books']
# ['Plate (folio 8) from LE STANZE OSCURE', 'Cesare Peverelli', 'Italian', 1922, 2000, 'Male', 1965, 'Prints & Illustrated Books']
# ['Photographic Views and Studies of Canadian Scenery', 'Alexander Henderson', 'Canadian', 1831, 1913, 'Male', 1865, 'Photography']
# ['Georgetown County Court House, Georgetown, South Carolina, February 20, 1976', 'Stephen Shore', 'American', 1947, '', 'Male', 1976, 'Photography']
# ['Meudon, ancien château', 'Eugène Atget', 'French', 1857, 1927, 'Male', 1902, 'Photography']
# ['Bright Leaves', 'Ross McElwee', 'Nationality Unknown', '', '', 'Male', 2003, 'Film']
# ['A Mounatin Called Desire (Una Montaña llamada deseo)', 'Sandra Vásquez de la Horra', 'Chilean', 1967, '', 'Female', 2010, 'Drawings']
# ['Plate XLVII from the Barcelona Series', 'Joan Miró', 'Spanish', 1893, 1983, 'Male', 1944, 'Prints & Illustrated Books']
# ['Canto VI from 18 Cantos', 'Barnett Newman', 'American', 1905, 1970, 'Male', 1963, 'Prints & Illustrated Books']
# ['Chagres River from the Fort', 'Eadweard J. Muybridge', 'American', 1830, 1904, 'Male', 1875, 'Photography']
# ['Men of Air, New York', 'Robert Frank', 'American', 1924, '', 'Male', 1948, 'Photography']
# ['William Eggleston and Friend', 'Lee Friedlander', 'American', 1934, '', 'Male', 1990, 'Photography']
# ['Seated Nude', 'Fernand Léger', 'French', 1881, 1955, 'Male', 1913, 'Drawings']
# ['Extraordinary Contorted "Marble Cake" Moraine of Susitna Glacier, Central Alaska', 'Bradford Washburn', 'American', 1910, 2007, 'Male', 1958, 'Photography']
# ['Friedrichstrasse Skyscraper Project, Berlin-Mitte, Germany (Floor plan)', 'Ludwig Mies van der Rohe', 'American', 1886, 1969, 'Male', 1921, 'Architecture & Design']
# ['Ouray from Copper Series', 'Frank Stella', 'American', 1936, '', 'Male', 1970, 'Prints & Illustrated Books']
# ['Bodies of Women (Corps de dames)', 'Jean Dubuffet', 'French', 1901, 1985, 'Male', 1950, 'Prints & Illustrated Books']
# ['Ear', 'Louise Bourgeois', 'American', 1911, 2010, 'Female', 2004, 'Prints & Illustrated Books']
# ['Pablo Picasso', 'Man Ray (Emmanuel Radnitzky)', 'American', 1890, 1976, 'Male', 1926, 'Photography']
# ['Plate (folio 43) from ADVENTURES IN KU-TA-BA WA-DO', 'Gerald Jackson', 'American', 1943, '', 'Male', 1973, 'Prints & Illustrated Books']
# ['RETURN FROM TOIL', 'John Sloan', 'American', 1871, 1951, 'Male', 1915, 'Prints & Illustrated Books']
# ['Ears', 'Louise Bourgeois', 'American', 1911, 2010, 'Female', 2003, 'Prints & Illustrated Books']
# ['Blue Jean from AGPA 73: Pan American Graphic Arts (AGPA 73: Artes gráficas panamericanas)', 'Miguel Angel Rojas', 'Colombian', 1946, '', 'Male', 1973, 'Prints & Illustrated Books']
# ['J.A.B. AND HIS UMBRELLA', 'Stephen Scheer', 'American', 1954, '', 'Male', 1986, 'Photography']
# ['Tube', 'Roman Signer', 'Swiss', 1938, '', 'Male', 1982, 'Media and Performance Art']
# ['In-text plate (page 78) from LYSISTRATA', 'František Kupka', 'Czech', 1871, 1957, 'Male', 1910, 'Prints & Illustrated Books']
# ['German People - German Work Exhibit, Berlin, Germany, Installation of the vitrine for crystal glass. Elevation, plan, and sections.', 'Lilly Reich', 'German', 1885, 1947, 'Female', 1934, 'Architecture & Design']
# ['Plate (page 44) from PARADISE GARDEN', 'Sidney Nolan', 'Australian', 1917, 1992, 'Male', 1971, 'Prints & Illustrated Books']
# ['SALUTATIONS, SENOR!', 'George Overbury ("Pop") Hart', 'American', 1868, 1933, 'Male', 1926, 'Prints & Illustrated Books']
# ['NUMBER 12', 'Antoni Tàpies', 'Spanish', 1923, 2012, 'Male', 1960, 'Prints & Illustrated Books']
# ['50,000 Meals Served (50,000 Cubiertos)', 'José Chávez Morado', 'Mexican', 1909, 2002, 'Male', 1939, 'Prints & Illustrated Books']
# ["In-text plate (page 68) from LE VOYAGE D'URIEN", 'Maurice Denis', 'French', 1870, 1943, 'Male', 1893, 'Prints & Illustrated Books']
# ['Kaleidoscope #2 (Furnishing fabric)', 'Herbert Bayer', 'American', 1900, 1985, 'Male', 1952, 'Architecture & Design']
# ['Nations', 'Slavs and Tatars', 'Nationality Unknown', 2005, '', 'Gender Unknown/Other', 2007, 'Prints & Illustrated Books']
# ['THE WINE PRESS IN OPEN AIR (plate; volume I, page 147) from LES GÉORGIQUES (GEORGICA)', 'André Dunoyer de Segonzac', 'French', 1884, 1974, 'Male', 1940, 'Prints & Illustrated Books']
# ['The Brown Sisters, Marblehead, Massachusetts', 'Nicholas Nixon', 'American', 1947, '', 'Male', 1995, 'Photography']
# ['Linear Still Life', 'William Scott', 'British', 1913, 1989, 'Male', 1973, 'Drawings']
# ['Blind Man and His Son (Homem cego e seu filho)', 'Candido Portinari', 'Brazilian', 1903, 1962, 'Male', 1939, 'Prints & Illustrated Books']
# ['Street, Berlin', 'Ernst Ludwig Kirchner', 'German', 1880, 1938, 'Male', 1913, 'Painting & Sculpture']
# ['The Song of the Shirt', 'David Wark Griffith', 'American', 1874, 1948, 'Male', 1908, 'Film']
# ['Architecture Panoramas', 'Jan Dibbets', 'Dutch', 1941, '', 'Male', 1971, 'Photography']
# ['Kazimierz Malewicz 1876-1935', 'Wladyslaw Strzemiński', 'Polish', 1893, 1952, 'Male', 1936, 'Prints & Illustrated Books']
# ['Ausstellung Galerie St. Stephen Wien, Images Meditatives', 'Winfred Gaul', 'German', 1928, 2003, 'Male', 1960, 'Architecture & Design']
# ['Hospital Event Label', 'George Maciunas', 'American', 1931, 1978, 'Male', 1975, 'Prints & Illustrated Books']
# ['Washington, D.C.', 'Lee Friedlander', 'American', 1934, '', 'Male', 1976, 'Photography']
# ['Deeparture', 'Mircea Cantor', 'Romanian', 1977, '', 'Male', 2005, 'Media and Performance Art']
# ['Programy skolskeho rozhlasu', 'Augustin Tschinkel', 'Czech', 1905, '', 'Male', 1933, 'Architecture & Design']
# ['Plate (folio 19) from KAFKA', 'Roger Chancel', 'French', 1898, 1976, 'Male', 1957, 'Prints & Illustrated Books']
# ['Lassaw at Kootz Gallery', 'Elaine Lustig Cohen', 'American', 1927, 2016, 'Female', 1960, 'Architecture & Design']
# ['Untitled, from Eurana Park, Weatherly, Pennsylvania', 'Judith Joy Ross', 'American', 1946, '', 'Female', 1982, 'Photography']
# ['View from Hotel Window--Butte, Montana', 'Robert Frank', 'American', 1924, '', 'Male', 1956, 'Photography']
# ['CUPID SHOOTS THE WOMAN FROM HAMBURG IN THE STOMACH (in-text plate, page 20) from AUS DEN MEMOIREN DES HERRN VON SCHNABELEWOPSKY', 'Jules Pascin', 'American', 1885, 1930, 'Male', 1910, 'Prints & Illustrated Books']
# ['UNTITLED (SQUARE YELLOW SPIRAL)', 'Paul Thek', 'American', 1933, 1988, 'Male', 1983, 'Drawings']
# ['In-text plate (folio 5) from THE DONKEY AND THE DARLING', 'Larry Rivers', 'American', 1923, 2002, 'Male', 1972, 'Prints & Illustrated Books']
# ['So What!', 'Christian Fossier', 'French', 1943, 2013, 'Male', 1969, 'Prints & Illustrated Books']
# ['Plate 8 (in-text plate, folio 18) from UN SOUPÇON', 'Michel Guino', 'French', 1926, 2013, 'Male', 1965, 'Prints & Illustrated Books']
# ['Trinket', 'Arthur B. Davies', 'American', 1862, 1928, 'Male', 1920, 'Prints & Illustrated Books']
# ['SOBAKÉVITCH AT THE TABLE, plate XXXVI (facing page 130) from LES ÂMES MORTES', 'Marc Chagall', 'French', 1887, 1985, 'Male', 1936, 'Prints & Illustrated Books']
# ['Untitled (white lines)', 'Lauretta Vinciarelli', 'Italian', 1943, 2012, 'Female', 1973, 'Architecture & Design']
# ['GALATEA PLAYING IN WATER (in-text plate, page 68) from LES ÉGLOGUES', 'Aristide Maillol', 'French', 1861, 1944, 'Male', 1919, 'Prints & Illustrated Books']
# ['Mrs. Beatrice Baxter Ruyl and Infant', 'Gertrude Käsebier', 'American', 1852, 1934, 'Female', 1905, 'Photography']
# ['Plate (folio 12, duplicate of folio 10 woodcut) from Vingt-cinq poèmes', 'Jean (Hans) Arp', 'French', 1886, 1966, 'Male', 1918, 'Prints & Illustrated Books']
# ['Topiary', 'Louise Bourgeois', 'American', 1911, 2010, 'Female', 1997, 'Drawings']
# ['Ruins of the Church of Las Monjas, Old Panama', 'Eadweard J. Muybridge', 'American', 1830, 1904, 'Male', 1875, 'Photography']
# ['FONTAINE MOLIÈRE. RUE RICHELIEU. PAR VISCONTI ET PRADIER', 'Eugène Atget', 'French', 1857, 1927, 'Male', 1907, 'Photography']
# ['Reclining Chair without Arms (Perspective sketch)', 'Ludwig Mies van der Rohe', 'American', 1886, 1969, 'Male', 1936, 'Architecture & Design']
# ['Ileana from Ruminations', 'Robert Rauschenberg', 'American', 1925, 2008, 'Male', 1999, 'Prints & Illustrated Books']
# ['Luz Seated (to the right)', 'Jean Charlot', 'American', 1898, 1979, 'Male', 1929, 'Prints & Illustrated Books']
# ['Untitled, from the series Come Sunday', 'Thomas Roma', 'American', 1950, '', 'Male', 1992, 'Photography']
# ['Black Panther children in a classroom at the Intercommunal Youth Institute, the Black Panther school, Oakland, California', 'Stephen Shames', 'American', 1947, '', 'Male', 1971, 'Photography']
# ['Wear Your Goggles', 'Pat Keely', 'British', '', '', 'Male', 1942, 'Architecture & Design']
# ['Ballet poster', 'André Masson', 'French', 1896, 1987, 'Male', 1933, 'Architecture & Design']
# ['Fingerprint', 'Robert Watts', 'American', 1923, 1988, 'Male', 1965, 'Prints & Illustrated Books']
# ['El Frente Popular de Madrid Al Frente Popular del Mundo - Homenaje a Las Brigadas Internacionales', 'J. Briones', 'Spanish', '', '', 'Gender Unknown/Other', 1936, 'Architecture & Design']
# ['Untitled from Woodcuts', 'Thomas Schütte', 'German', 1954, '', 'Male', 2011, 'Prints & Illustrated Books']
# ['PSALM 122, plate 27 (page 61) from PSAUMES DE DAVID', 'Marc Chagall', 'French', 1887, 1985, 'Male', 1978, 'Prints & Illustrated Books']
# ['New York I', 'Aaron Siskind', 'American', 1903, 1991, 'Male', 1951, 'Photography']
# ['Weissenhof Housing Colony Master Plan, "The Dwelling," Stuttgart, Germany, Site elevation study from east', 'Ludwig Mies van der Rohe', 'American', 1886, 1969, 'Male', 1926, 'Architecture & Design']
# ["Ode à l'Oubli", 'Louise Bourgeois', 'American', 1911, 2010, 'Female', 2004, 'Prints & Illustrated Books']
# ['Two Figures', 'Max Weber', 'American', 1881, 1961, 'Male', 1920, 'Prints & Illustrated Books']
# ['Instruction No. 2 from Fluxkit', 'Benjamin Patterson', 'American', 1934, 2016, 'Male', 1966, 'Prints & Illustrated Books']
# ['Untitled', 'Unknown', 'Nationality Unknown', '', '', 'Gender Unknown/Other', 1937, 'Photography']
# ['In-text plate (folio 8) from The Adventures of a Novel in Four Chapters', 'Bruce Conner', 'American', 1933, 2008, 'Male', 1991, 'Prints & Illustrated Books']
# ['Headpiece (page 17) from RÉINCARNATIONS DU PÈRE UBU', 'Georges Rouault', 'French', 1871, 1958, 'Male', 1924, 'Prints & Illustrated Books']
# ['Cloud Rock (plate, page 78) from 1¢ Life', 'Sam Francis', 'American', 1923, 1994, 'Male', 1964, 'Prints & Illustrated Books']
# ['Untitled from an untitled portfolio', 'Mateo Manaure', 'Venezuelan', 1926, 2018, 'Male', 1969, 'Prints & Illustrated Books']
# ['Untitled from Traces of anonymous pupil authors', 'Haegue Yang', 'Korean', 1971, '', 'Female', 2001, 'Prints & Illustrated Books']
# ['Tailpiece (page 81) from ODES', 'André Derain', 'French', 1880, 1954, 'Male', 1953, 'Prints & Illustrated Books']
# ['Salt Lake City', 'Lee Friedlander', 'American', 1934, '', 'Male', 1965, 'Photography']
# ['Château de Bagatelle', 'Eugène Atget', 'French', 1857, 1927, 'Male', 1913, 'Photography']
# ["Tailpiece (page 171) from L'ODYSSÉE", 'Émile Bernard', 'French', 1868, 1941, 'Male', 1930, 'Prints & Illustrated Books']
# ['The Orchestra', 'Walter Richard Sickert', 'British', 1860, 1942, 'Male', 1905, 'Prints & Illustrated Books']
# ['Untitled, no. 1 of 12, from the illustrated book, To Whom It May Concern', 'Louise Bourgeois', 'American', 1911, 2010, 'Female', 2010, 'Prints & Illustrated Books']
# ['Untitled from Farewell', 'Moshe Gershuni', 'Israeli', 1936, 2017, 'Male', 1992, 'Prints & Illustrated Books']
# ['Midway Gardens, Chicago, IL', 'Frank Lloyd Wright', 'American', 1867, 1959, 'Male', 1913, 'Architecture & Design']
# ['DEATH OF MOSES, plate 41 (volume, folio 90) from the BIBLE', 'Marc Chagall', 'French', 1887, 1985, 'Male', 1944, 'Prints & Illustrated Books']
# ['She-Paul-A-Wee', 'William Henry Jackson', 'American', 1843, 1942, 'Male', 1875, 'Photography']
# ['Volcano', 'Roman Signer', 'Swiss', 1938, '', 'Male', 1989, 'Media and Performance Art']
# ['Palmolive', 'George Brecht', 'American', 1926, 2008, 'Male', 1962, 'Prints & Illustrated Books']
# ["Untitled from Andy Warhol Doesn't Play Second Base for the Chicago Cubs", 'Kelley Walker', 'American', 1969, '', 'Male', 2010, 'Prints & Illustrated Books']
# ['Portrait of Mies from Fluxus 1', 'George Maciunas', 'American', 1931, 1978, 'Male', 1964, 'Prints & Illustrated Books']
# ['Great Builders II', 'Jean Charlot', 'American', 1898, 1979, 'Male', 1927, 'Prints & Illustrated Books']
# ['Motherfucker from The Bad Habits', 'Lisa Yuskavage', 'American', 1962, '', 'Female', 1997, 'Prints & Illustrated Books']
# ['Entrance to Rockcut Dwelling, Bandelier National Monument', 'William R. Current', 'American', 1923, '', 'Male', 1962, 'Photography']
# ['Three Kids and a Sled', 'Philip Fein', 'American', 1912, 1994, 'Male', 1940, 'Photography']
# ['Study of Kuang Kung', 'Seong Moy', 'American', 1921, 2013, 'Male', 1952, 'Prints & Illustrated Books']
# ['Abacus (Furnishing fabric)', 'Paul Rand', 'American', 1914, 1996, 'Male', 1946, 'Architecture & Design']
# ['Venezuela', 'Dorothea Lange', 'American', 1895, 1965, 'Female', 1960, 'Photography']
# ['Ancien Couvent des Bénédictins anglais, 269 bis rue Saint-Jacques', 'Eugène Atget', 'French', 1857, 1927, 'Male', 1900, 'Photography']
# ['Sky Backdrop', 'Alex Israel', 'American', 1982, '', 'Male', 2013, 'Painting & Sculpture']
# ['Union der Sozialistischen Sowjet-Republiken: Pressa Köln (Union of Socialist Soviet Republics)', 'El Lissitzky', 'Russian', 1890, 1941, 'Male', 1928, 'Prints & Illustrated Books']
# ['New York City', 'Lee Friedlander', 'American', 1934, '', 'Male', 1978, 'Photography']
# ['Progressive IV for VENTRILOQUIST', 'Jasper Johns', 'American', 1930, '', 'Male', 1986, 'Prints & Illustrated Books']
# ['Untitled', 'Eugène Atget', 'French', 1857, 1927, 'Male', 1900, 'Photography']
# ['Plate (facing page 118) from SAINTE MONIQUE', 'Pierre Bonnard', 'French', 1867, 1947, 'Male', 1925, 'Prints & Illustrated Books']
# ['Museum', 'Peter Blume', 'American', 1906, 1992, 'Male', 1932, 'Drawings']
# ['Folio', 'Terry Winters', 'American', 1949, '', 'Male', 1986, 'Prints & Illustrated Books']
# ['Duino', 'César Paternosto', 'Argentine', 1931, '', 'Male', 1966, 'Painting & Sculpture']
# ['Unmade Bed', 'Joe Goode', 'American', 1937, '', 'Male', 1968, 'Painting & Sculpture']
# ['#2 from an untitled series', 'Larry Bell', 'American', 1939, '', 'Male', 1974, 'Prints & Illustrated Books']
# ['Untitled from Notes on a Room', 'Richard Artschwager', 'American', 1923, 2013, 'Male', 1998, 'Prints & Illustrated Books']
# ['Untitled', 'Dan McCarthy', 'American', 1962, '', 'Male', 2000, 'Drawings']
# ['Untitled', 'Wade Guyton', 'American', 1972, '', 'Male', 2006, 'Painting & Sculpture']
# ['French Embassy Staff Quarters, New Delhi, India', 'Raj Rewal', 'Indian', 1934, '', 'Male', 1967, 'Architecture & Design']
# ['Plate (folio 9) from HIOB', 'Hella Fischer-Thorer', 'German', 1928, 1978, 'Female', 1965, 'Prints & Illustrated Books']
# ['Z. I. Gorbovets. Graviury na dereve', 'Zinovii Gorbovets', 'Nationality Unknown', '', '', 'Gender Unknown/Other', 1927, 'Prints & Illustrated Books']
# ['Lapeyrouse Wall', 'Peter Doig', 'British', 1959, '', 'Male', 2004, 'Painting & Sculpture']
# ['The Language of Fashion (El lenguaje de la moda)', 'Juan Luis Martinez', 'Chilean', 1942, 1993, 'Male', 1979, 'Drawings']
# ['Adam', 'Amedeo Modigliani', 'Italian', 1884, 1920, 'Male', 1916, 'Drawings']
# ['Untitled from Pisueña', 'Juan Uslé', 'Spanish', 1954, '', 'Male', 2009, 'Prints & Illustrated Books']
# ["Roberta's Excorcism Flower Arrangements", 'Lynn Hershman Leeson', 'American', 1941, '', 'Female', 1978, 'Photography']
# ['(Number 1 of a newspaper campaign)', 'Karl Gerstner', 'Swiss', 1930, '', 'Male', 1964, 'Architecture & Design']
# ['Untitled', 'Nathan Lyons', 'American', 1930, 2016, 'Male', 1958, 'Photography']
# ['Femme de Verrières', 'Eugène Atget', 'French', 1857, 1927, 'Male', 1900, 'Photography']
# ['Public Sculptures in Public Places', 'Bob Cato', 'Nationality Unknown', 1923, '', 'Male', 1967, 'Architecture & Design']
# ['Double page plate (pages 20 and 21) from TAGEBÜCHER', 'Antonio Saura', 'Spanish', 1930, 1998, 'Male', 1988, 'Prints & Illustrated Books']
# ['Plate (page 215) from LES PETITES FLEURS', 'Émile Bernard', 'French', 1868, 1941, 'Male', 1928, 'Prints & Illustrated Books']
# ["Untitled from the series 'Ten Thousand Things That Breathe'", 'Renato Orara', 'American', 1961, '', 'Male', 2003, 'Drawings']
# ['Jardin de Luxembourg', 'Pavel Tchelitchew', 'American', 1898, 1957, 'Male', 1924, 'Drawings']
# ['Vocal Group Niji', 'Tadanori Yokoo', 'Japanese', 1936, '', 'Male', 1964, 'Architecture & Design']
# ['Untitled', 'Unknown', 'Nationality Unknown', '', '', 'Gender Unknown/Other', 1900, 'Photography']
# ['Sex Pistols Flyer', 'Jamie Reid', 'British', 1947, '', 'Male', 1975, 'Architecture & Design']
# ['Milk Stone', 'Wolfgang Laib', 'German', 1950, '', 'Male', 1978, 'Painting & Sculpture']
# ['ECCE HOMO, plate XVIII (folio 21) from SCÈNES DE LA VIE DU CHRIST', 'James Ensor', 'Belgian', 1860, 1949, 'Male', 1917, 'Prints & Illustrated Books']
# ['(Portrait)', 'Alfred Capel Cure', 'British', 1826, 1896, 'Male', 1861, 'Photography']
# ['Upholstery Material', 'Anni Albers', 'American', 1899, 1994, 'Female', 1929, 'Architecture & Design']
# ['Double page fold-out plate (folios 17 and 18) from PICCOLO CIRCOLO CHIUSO', 'Mimmo Paladino', 'Italian', 1948, '', 'Male', 1991, 'Prints & Illustrated Books']
# ['The Unfinished Conversation', 'John Akomfrah', 'British', 1957, '', 'Male', 2012, 'Media and Performance Art']
# ["In-text plate (page 138) from CIRQUE DE L'ÉTOILE FILANTE", 'Georges Rouault', 'French', 1871, 1958, 'Male', 1932, 'Prints & Illustrated Books']
# ['Nancy', 'Nancy Hellebrand', 'American', 1944, '', 'Female', 1982, 'Photography']
# ['Untitled. (man with a fish)', 'Dorothea Lange', 'American', 1895, 1965, 'Female', 1963, 'Photography']
# ['TARGET from an untitled portfolio', 'Ronald Markman', 'American', 1931, '', 'Male', 1962, 'Prints & Illustrated Books']
# ['Schema I: Construction of Axes of a Model; Schema II: Cubist Structure (Construction); and Schema III: Cubist Constructed Drawing from On New Systems in Art (O Novykh Sistemakh Visk Usstve)', 'Kazimir Malevich', 'Russian', 1878, 1935, 'Male', 1919, 'Prints & Illustrated Books']
# ['Light Trails', 'William Wegman', 'American', 1943, '', 'Male', 1970, 'Media and Performance Art']
# ['Plate IV (folio 7) from FROM JEWISH POEMS', 'Maurice Grosman', 'American', 1900, 1976, 'Male', 1962, 'Prints & Illustrated Books']
# ['The Guilty Girl Is Fragile', 'Louise Bourgeois', 'American', 1911, 2010, 'Female', 2000, 'Prints & Illustrated Books']
# ['Untitled', 'Jarrod Beck', 'American', 1977, '', 'Male', 2004, 'Drawings']
# ['Covent Garden Labourers', 'John Thomson', 'British', 1837, 1921, 'Male', 1877, 'Photography']
# ['On the Fortress', 'Jules Pascin', 'American', 1885, 1930, 'Male', 1914, 'Prints & Illustrated Books']
# ['In-text plate (folio 13 verso) from LA MÉTROMANIE', 'Jean Dubuffet', 'French', 1901, 1985, 'Male', 1950, 'Prints & Illustrated Books']
# ['Urchin in the Grass', 'Richard Stankiewicz', 'American', 1922, 1983, 'Male', 1956, 'Painting & Sculpture']
# ['Untitled from Full Moon in Aries (Vollmond im Widder)', 'Sigmar Polke', 'German', 1941, 2010, 'Male', 2004, 'Prints & Illustrated Books']
# ['Sketchbook: El Golea, II', 'Jean Dubuffet', 'French', 1901, 1985, 'Male', 1948, 'Drawings']
# ['Saint-Cloud', 'Eugène Atget', 'French', 1857, 1927, 'Male', 1922, 'Photography']
# ['#3 Looking Ahead? So Are We!', 'Ay-O', 'Japanese', 1931, '', 'Male', 1965, 'Prints & Illustrated Books']
# ['Headpiece (page 97) from POÈMES', 'Charles Despiau', 'French', 1874, 1946, 'Male', 1933, 'Prints & Illustrated Books']
# ['The Pool - Deal', 'Alfred Stieglitz', 'American', 1864, 1946, 'Male', 1910, 'Photography']
# ['Pont Neuf: The Localization of a Tetrahedron in Space from Artists & Photographs', 'Michael Kirby', 'American', 1931, '', 'Male', 1970, 'Prints & Illustrated Books']
# ["Headpiece (page 9) from POÈME DE L'ANGLE DROIT", 'Le Corbusier (Charles-Édouard Jeanneret)', 'French', 1887, 1965, 'Male', 1951, 'Prints & Illustrated Books']
# ["I'se Awake", 'John McGreer', 'American', '', '', 'Male', 1881, 'Photography']
# ['"A Famous Fisherman in Action"', 'Times Wide World Photos', 'American', 1919, 1941, 'Gender Unknown/Other', 1932, 'Photography']
# ['Untitled (for Parkett no. 76)', 'Lucy McKenzie', 'British', 1977, '', 'Female', 2006, 'Prints & Illustrated Books']
# ['Sleeping Figure', 'Conrad Marca-Relli', 'American', 1913, 2000, 'Male', 1954, 'Painting & Sculpture']
# ['2nd variant of ...SHE PLACES HER CHEEK THERE... SHE EMBRACES IT... (volume II, folio 8) from PASIPHAÉ', 'Henri Matisse', 'French', 1869, 1954, 'Male', 1962, 'Prints & Illustrated Books']
# ['Evelyn Phetteplace, Shannon Sopko, Cambridge', 'Nicholas Nixon', 'American', 1947, '', 'Male', 1994, 'Photography']
# ['Grace in Window', 'Tanyth Berkeley', 'American', 1969, '', 'Female', 2006, 'Photography']
# ['TWO PART INVENTIONS', 'James McGarrell', 'American', 1930, '', 'Male', 1965, 'Prints & Illustrated Books']
# ["Plants, Cahows's Barber Shop, Chapman, Nebraska", 'Wright Morris', 'American', 1910, 1998, 'Male', 1942, 'Photography']
# ['ELIJAH TOUCHED BY AN ANGEL, plate 87 (volume II, folio 64) from the BIBLE', 'Marc Chagall', 'French', 1887, 1985, 'Male', 1944, 'Prints & Illustrated Books']
# ['LORD WHO GATHERS OUR EXILES (plate, folio 12) from THE SILENT PRAYER', 'Peter Freudenthal', 'Swedish', 1938, '', 'Male', 1977, 'Prints & Illustrated Books']
# ['Holy Redeemer Church, San Cristóbal de la Laguna, Tenerife, Spain (Elevation and perspective sketches)', 'Fernando Martín Menis', 'Spanish', 1951, '', 'Male', 2005, 'Architecture & Design']
# ['Dziady', 'Roman Cieslewicz', 'French', 1930, 1996, 'Male', 1967, 'Architecture & Design']
# ['Untitled from Eight Variations for Heiner Friedrich Gallery (Acht Variationen für die Galerie Heiner Friedrich)', 'Fred Sandback', 'American', 1943, 2003, 'Male', 1972, 'Prints & Illustrated Books']
# ['Self-Portrait', 'Arch Connelly', 'American', 1950, 1993, 'Male', 1981, 'Painting & Sculpture']
# ['Richard Pousette-Dart Masher', 'Ray Johnson', 'American', 1927, 1995, 'Male', 1972, 'Drawings']
# ['Backyard--Venice West, California', 'Robert Frank', 'American', 1924, '', 'Male', 1956, 'Photography']
# ['Stay the Same Never Change', 'Laurel Nakadate', 'American', 1975, '', 'Female', 2008, 'Film']
# ['Ireland', 'Henri Cartier-Bresson', 'French', 1908, 2004, 'Male', 1963, 'Photography']
# ['First state of plate 6 (folio 34) from QUATRE HISTOIRES DE BLANC ET NOIR', 'František Kupka', 'Czech', 1871, 1957, 'Male', 1926, 'Prints & Illustrated Books']
# ['Combegrasse, Puy de Dome', 'Jacques-Henri Lartigue', 'French', 1894, 1986, 'Male', 1922, 'Photography']
# ['Flag', 'James Riddle', 'American', 1933, '', 'Male', 1964, 'Fluxus Collection']
# ['Arithmetic: Class studying under the Spear method', 'Frances Benjamin Johnston', 'American', 1864, 1952, 'Female', 1900, 'Photography']
# ["Duplicate of in-text plate from page 139 (2nd supplementary suite, plate 16) from TÊTE D'OR", 'Roger de La Fresnaye', 'French', 1885, 1925, 'Male', 1930, 'Prints & Illustrated Books']
# ['Rainbow, Lake George', 'Alfred Stieglitz', 'American', 1864, 1946, 'Male', 1920, 'Photography']
# ['Attaque', 'Louise Bourgeois', 'American', 1911, 2010, 'Female', 1948, 'Prints & Illustrated Books']
# ['The Mile-High Illinois, Chicago Project (Dedication to famous architects and engineers and height comparisons to the Washington Monument, Great Pyramid of Giza, Eiffel Tower, and Empire State Building)', 'Frank Lloyd Wright', 'American', 1867, 1959, 'Male', 1956, 'Architecture & Design']
# ['Untitled', 'Jene Highstein', 'American', 1942, '', 'Male', 1982, 'Prints & Illustrated Books']
# ['Variant of in-text plate from page 79 with +remarque- (supplementary suite, plate 30) from LYSISTRATA', 'František Kupka', 'Czech', 1871, 1957, 'Male', 1910, 'Prints & Illustrated Books']
# ['FIGURE (plate, page 13) from DU CUBISME', 'André Derain', 'French', 1880, 1954, 'Male', 1947, 'Prints & Illustrated Books']
# ['Lithograph II (plate, page 21) from REPLI', 'Henri Matisse', 'French', 1869, 1954, 'Male', 1946, 'Prints & Illustrated Books']
# ["J.R. Butler, President of the Southern Tenant Farmers' Union, Memphis, Tennessee", 'Dorothea Lange', 'American', 1895, 1965, 'Female', 1938, 'Photography']
# ['Untitled from Spirit Cooking', 'Marina Abramović', 'Yugoslav', 1946, '', 'Female', 1996, 'Prints & Illustrated Books']
# ['Dr. Scud Fly Swatter', 'Philippe Starck', 'French', 1949, '', 'Male', 1998, 'Architecture & Design']
# ['In-text plate (page 14) from TAGEBÜCHER', 'Antonio Saura', 'Spanish', 1930, 1998, 'Male', 1988, 'Prints & Illustrated Books']
# ['For Father Berrigan', 'Llyn Foulkes', 'American', 1934, '', 'Male', 1973, 'Painting & Sculpture']
# ['Essene', 'Frederick Wiseman', 'American', 1930, '', 'Male', 1972, 'Film']
# ['Plate (folio 11) from LA VITTORIA', 'Jean Tinguely', 'Swiss', 1925, 1991, 'Male', 1971, 'Prints & Illustrated Books']
# ['Untitled', 'Unknown', 'Nationality Unknown', '', '', 'Gender Unknown/Other', 1926, 'Photography']
# ['Banco Pinto & Sotto Mayor, Oliveira de Azeméis, Portugal (Plan and perspective sketches)', 'Álvaro Siza', 'Portuguese', 1933, '', 'Male', 1972, 'Architecture & Design']
# ['1 mark note (Emergency currency issued by the city of Itzehoe)', 'Wenzel Hablik', 'German', 1881, 1934, 'Male', 1921, 'Architecture & Design']
# ['Scores (pages 5-6) from Fluxus 1', 'Emmett Williams', 'American', 1925, 2007, 'Male', 1964, 'Prints & Illustrated Books']
# ['In-text plate (page 108) from PANTAGRUEL', 'André Derain', 'French', 1880, 1954, 'Male', 1943, 'Prints & Illustrated Books']
# ['Smoke on Cellophane 5', 'Frederick Sommer', 'American', 1905, 1999, 'Male', 1961, 'Photography']
# ["Stalin's Great Aunt", 'Margaret Bourke-White', 'American', 1904, 1971, 'Female', 1935, 'Photography']
# ['Mother and Child', 'Wifredo Lam', 'Cuban', 1902, 1982, 'Male', 1939, 'Drawings']
# ['Drawing for Excreta Fluxorum', 'George Maciunas', 'American', 1931, 1978, 'Male', 1977, 'Prints & Illustrated Books']
# ['Are we losing touch?', 'Friedrich Kunath', 'German', 1974, '', 'Male', 2003, 'Drawings']
# ['Untitled', 'Almir Mavignier', 'Brazilian', 1925, '', 'Male', 1961, 'Prints & Illustrated Books']
# ['Untitled (4 days, 3 nights, 1 summer)', 'Joey Kötting', 'British', 1966, '', 'Male', 2001, 'Prints & Illustrated Books']
# ['Color separations for LOISIRS', 'Jean Dubuffet', 'French', 1901, 1985, 'Male', 1966, 'Prints & Illustrated Books']
# ["Wayne County & the Backstreet Boys at Max's", 'Unknown', 'American', '', '', 'Gender Unknown/Other', 1975, 'Architecture & Design']
# ['International Film Festival', 'Unknown', 'Nationality Unknown', '', '', 'Gender Unknown/Other', 1926, 'Architecture & Design']
# ['Untitled', 'Mateo López', 'Colombian', 1978, '', 'Male', 2009, 'Drawings']
# ['Haiti, Port-au-Prince, Cemetery', 'Bruce Gilden', 'American', 1946, '', 'Male', 1988, 'Photography']
# ['Ship Construction, Bath, Maine', 'Clarence H. White', 'American', 1871, 1925, 'Male', 1917, 'Photography']
# ['Composition of Circles and Overlapping Angles', 'Sophie Taeuber-Arp', 'Swiss', 1889, 1943, 'Female', 1930, 'Painting & Sculpture']
# ['Reste', 'Arnulf Rainer', 'Austrian', 1929, '', 'Male', 1978, 'Prints & Illustrated Books']
# ['Color Wheel (for Parkett no. 81)', 'Cosima von Bonin', 'German', 1962, '', 'Female', 2007, 'Prints & Illustrated Books']
# ['The Little Tear Gland That Says Tic Tac (La Petite fistule lacrimale qui dit tic tac)', 'Max Ernst', 'French', 1891, 1976, 'Male', 1920, 'Drawings']
# ['In-text plate (page 165) from DAPHNIS ET CHLOÉ', 'Pierre Bonnard', 'French', 1867, 1947, 'Male', 1902, 'Prints & Illustrated Books']
# ['Headpiece (page 67) from FABLES', 'Thomas Bewick', 'British', 1753, 1828, 'Male', 1818, 'Prints & Illustrated Books']
# ['For the Benefit of Native Children (A Beneficio del Niño indigena)', 'Isidoro Ocampo', 'Mexican', 1910, 1983, 'Male', 1925, 'Prints & Illustrated Books']
# ['Untitled', 'Peter Booth', 'Australian', 1940, '', 'Male', 1984, 'Drawings']
# ['DWB Jahresversammlung', 'Herbert Bayer', 'American', 1900, 1985, 'Male', 1929, 'Architecture & Design']
# ['Untitled from the portfolio Souvenirs du Camp de Chalons', 'Gustave Le Gray', 'French', 1820, 1884, 'Male', 1857, 'Photography']
# ['11th variant of ...AND ONE MUST DIE WITHOUT KILLING THE WIND... (volume I, 11th unnumbered folio) from PASIPHAÉ', 'Henri Matisse', 'French', 1869, 1954, 'Male', 1962, 'Prints & Illustrated Books']
# ['Oklahoma', 'Lee Friedlander', 'American', 1934, '', 'Male', 1973, 'Photography']
# ['Reclining Chair with Rocker, with Arms (Perspective sketch)', 'Ludwig Mies van der Rohe', 'American', 1886, 1969, 'Male', 1934, 'Architecture & Design']
# ['Plate (folio 51) from Six Geometric Figures and All Their Combinations, Volume II', 'Sol LeWitt', 'American', 1928, 2007, 'Male', 1980, 'Prints & Illustrated Books']
# ['Margarethe Kleinschmidt in a Wicker Chair (Margarethe Kleinschmidt im Korbstuhl)', 'Paul Kleinschmidt', 'German', 1883, 1949, 'Male', 1921, 'Prints & Illustrated Books']
# ['Untitled, plate 9 of 9, from the illustrated book, Ode à Ma Mère', 'Louise Bourgeois', 'American', 1911, 2010, 'Female', 1995, 'Prints & Illustrated Books']
# ['Dusk, Yokohama', 'Daido Moriyama', 'Japanese', 1938, '', 'Male', 1969, 'Photography']
# ['Landscape Panoramas', 'Jan Dibbets', 'Dutch', 1941, '', 'Male', 1971, 'Photography']
# ['Broken Egg, New York', 'Irving Penn', 'American', 1917, 2009, 'Male', 1958, 'Photography']
# ['Ornamental initial V (page 8) from CANTICUM CANTICORUM SALOMONIS', 'Eric Gill', 'British', 1882, 1940, 'Male', 1931, 'Prints & Illustrated Books']
# ['Montgeron (Saules)', 'Eugène Atget', 'French', 1857, 1927, 'Male', 1926, 'Photography']
# ['Footprints from Traveling. Limit of Reach', 'Robert Morris', 'American', 1931, '', 'Male', 1976, 'Drawings']
# ['In-text plate (folio 34) from BIOTHERM', 'Jim Dine', 'American', 1935, '', 'Male', 1990, 'Prints & Illustrated Books']
# ['Vertical Horizontals', 'Hedda Sterne', 'American', 1910, '', 'Female', 1967, 'Prints & Illustrated Books']
# ['Duplicate of wrapper front (supplementary suite, wrapper front) from CONTES', 'Henri Laurens', 'French', 1885, 1954, 'Male', 1953, 'Prints & Illustrated Books']
# ['"UB"', 'Sergio Gonzalez-Tornero', 'Chilean', 1927, '', 'Male', 1961, 'Prints & Illustrated Books']
# ['Untitled', 'Francis Alÿs', 'Belgian', 1959, '', 'Male', 2000, 'Media and Performance Art']
# ['Composition', 'Luigi Veronesi', 'Italian', 1908, 1998, 'Male', 1935, 'Photography']
# ['Meredith Memorial Hall, Drake University, Des Moines, IA (Exterior elevation)', 'Ludwig Mies van der Rohe', 'American', 1886, 1969, 'Male', 1964, 'Architecture & Design']
# ['Armando Reverón', 'Carlos Herrera', 'Venezuelan', 1909, 1988, 'Male', 1940, 'Photography']
# ['Low Tide Wandering No. 7 (Wattwanderung No. 7) from Low Tide Wandering (Wattwanderung)', 'Thomas Schütte', 'German', 1954, '', 'Male', 2001, 'Prints & Illustrated Books']
# ['Untitled', 'Ernest J. Bellocq', 'American', 1873, 1949, 'Male', 1912, 'Photography']
# ['Plate (folio 32) from Capital in Pictures', 'Hugo Gellert', 'American', 1892, 1985, 'Male', 1933, 'Prints & Illustrated Books']
# ['Untitled', 'Rene Portocarrero', 'Cuban', 1914, 1985, 'Male', 1941, 'Drawings']
# ['Tout, no. 9', 'Ben Vautier', 'French', 1935, '', 'Male', 1965, 'Prints & Illustrated Books']
# ['Modena', 'Luigi Ghirri', 'Italian', 1943, 1992, 'Male', 1971, 'Photography']
# ['Tortilla Flaps', 'Robert McKimson', 'American', 1910, 1977, 'Male', 1958, 'Film']
# ['Models for Synthetic Pictures', 'Terry Winters', 'American', 1949, '', 'Male', 1994, 'Prints & Illustrated Books']
# ['Fluxus is always 6 a.m.', 'Nam June Paik', 'American', 1932, 2006, 'Male', 1976, 'Prints & Illustrated Books']
# ['The Farm', 'Louise Bourgeois', 'American', 1911, 2010, 'Female', 1940, 'Prints & Illustrated Books']
# ['Trembling Text (Texte frissonnant) from the portfolio Textures from Phenomena (Les Phénomènes)', 'Jean Dubuffet', 'French', 1901, 1985, 'Male', 1959, 'Prints & Illustrated Books']
# ['Library and Office Building of Salman Schocken, Jerusalem, Israel, Interior perspectives', 'Erich Mendelsohn', 'American', 1887, 1953, 'Male', 1935, 'Architecture & Design']
# ['Champfleurette, the White Cat', 'Louise Bourgeois', 'American', 1911, 2010, 'Female', 1993, 'Prints & Illustrated Books']
# ['Zen For Film', 'Nam June Paik', 'American', 1932, 2006, 'Male', 1965, 'Fluxus Collection']
# ['Experiment', 'Roman Signer', 'Swiss', 1938, '', 'Male', 1982, 'Media and Performance Art']
# ['Che', 'Francisco Blanco', 'Cuban', '', '', 'Male', 1972, 'Architecture & Design']
# ['Merry-go-round', 'Edward Dwurnik', 'Polish', 1943, '', 'Male', 1985, 'Prints & Illustrated Books']
# ['M.A.E., Boston', 'Nicholas Nixon', 'American', 1947, '', 'Male', 1985, 'Photography']
# ['Art & Project Bulletin #90', 'Richard Long', 'British', 1945, '', 'Male', 1975, 'Prints & Illustrated Books']
# ['Untitled from Favorite Objects', 'Christian Boltanski', 'French', 1944, '', 'Male', 1998, 'Prints & Illustrated Books']
# ['Cristo, Tlacochoaya, Oaxaca', 'Paul Strand', 'American', 1890, 1976, 'Male', 1933, 'Photography']
# ['Boxer [Hein Domgörgen]', 'August Sander', 'German', 1876, 1964, 'Male', 1923, 'Photography']
# ['German People - German Work Exhibit, Berlin, Germany, Final exhibit. Stove section. Plan.', 'Lilly Reich', 'German', 1885, 1947, 'Female', 1934, 'Architecture & Design']
# ['Untitled from Gloria', 'Alex Katz', 'American', 1927, '', 'Male', 2005, 'Prints & Illustrated Books']
# ['Seated Woman with Drapery', 'Gaston Lachaise', 'American', 1882, 1935, 'Male', 1930, 'Drawings']
# ['Clown and Child from Cirque', 'Georges Rouault', 'French', 1871, 1958, 'Male', 1930, 'Prints & Illustrated Books']
# ['Untitled #32', 'José Antonio Suárez Londoño', 'Colombian', 1955, '', 'Male', 1982, 'Prints & Illustrated Books']
# ['Repeat of pictorial initial L from page 14 (page 228) from LES PETITES FLEURS', 'Émile Bernard', 'French', 1868, 1941, 'Male', 1928, 'Prints & Illustrated Books']
# ['Untitled', 'Unknown', 'Nationality Unknown', '', '', 'Gender Unknown/Other', 1949, 'Photography']
# ['Zebra', 'Richard Francisco', 'American', 1942, '', 'Male', 1973, 'Drawings']
# ['Untitled', 'Unknown', 'Nationality Unknown', '', '', 'Gender Unknown/Other', 1930, 'Photography']
# ['Earnestly Exhorting the Cook to Protect Isabella', 'Peggy Bacon', 'American', 1895, 1987, 'Female', 1919, 'Prints & Illustrated Books']
# ['Marvin in Blue Sparkle Chair from God Love the Tragic Artist: Meg Cranston on the Life of Marvin Gaye', 'Meg Cranston', 'American', 1960, '', 'Female', 1995, 'Drawings']
# ['Factories, Lynn, Massachusetts', 'Walker Evans', 'American', 1903, 1975, 'Male', 1932, 'Photography']
# ['El fascismo. 7a. Conferencia: El fascismo japonés. Orador: Daniel Cosío Villegas. Viernes 9 de junio. Palacio de Bellas Artes... Liga Pro Cultura Alemana en México', 'Isidoro Ocampo', 'Mexican', 1910, 1983, 'Male', 1939, 'Prints & Illustrated Books']
# ['Reclining Chair without Arms (Elevation sketch)', 'Ludwig Mies van der Rohe', 'American', 1886, 1969, 'Male', 1931, 'Architecture & Design']
# ...
# ['Industries Carlos Cardoen of Santiago, Chile c. 1982-90 (2nd Version)', 'Mark Lombardi', 'American', 1951, 2000, 'Male', 2000, 'Drawings']
# ['Crucifixion', 'Lucio Fontana', 'Italian', 1899, 1968, 'Male', 1948, 'Painting & Sculpture']
# ['Black Book', 'Christopher Wool', 'American', 1955, '', 'Male', 1989, 'Prints & Illustrated Books']
# ['Splendor (Faste) from the portfolio Spectacles from Phenomena (Les Phénomènes)', 'Jean Dubuffet', 'French', 1901, 1985, 'Male', 1959, 'Prints & Illustrated Books']
# ['Gastronomie from Antinomian Press Archive', 'Ben Kinmont', 'American', 1963, '', 'Male', 2009, 'Prints & Illustrated Books']
# ['Das Stichwort: Magdeburger Blätter für Bühne, Musik und Gestaltende Arbeit, No. 11, Fasching', 'Xanti Schawinsky', 'American', 1904, 1979, 'Male', 1930, 'Architecture & Design']
# ['Just for You', 'Ken Friedman', 'American', 1939, '', 'Male', 1967, 'Prints & Illustrated Books']
# ['Title page from CALLIGRAMMES', 'Giorgio de Chirico', 'Italian', 1888, 1978, 'Male', 1930, 'Prints & Illustrated Books']
# ['I AM HE WHOM I HAVE SOUGHT, plate 8 (page 85) from THE LOVING SHEPHERDESS', 'Jean Kellogg', 'American', 1910, 1995, 'Female', 1956, 'Prints & Illustrated Books']
# ['PISAN FANCY (plate, page 51) from VIAGGIO IN ITALIA', 'Eugene Berman', 'American', 1899, 1972, 'Male', 1948, 'Prints & Illustrated Books']
# ['Mouth/Mouth', 'Carolee Schneemann', 'American', 1939, '', 'Female', 1997, 'Drawings']
# ["Wolf House, Gubin, Poland (Plan and elevations. Second floor children's study room.)", 'Ludwig Mies van der Rohe', 'American', 1886, 1969, 'Male', 1926, 'Architecture & Design']
# ['Oh Mummy Oh Daddy Show', 'Residents', 'American', 1972, '', 'Gender Unknown/Other', 1976, 'Film']
# ['Château Noir', 'Paul Cézanne', 'French', 1839, 1906, 'Male', 1904, 'Painting & Sculpture']
# ['Nobilissima Visione or St. Francis, design for ballet', 'Pavel Tchelitchew', 'American', 1898, 1957, 'Male', 1938, 'Drawings']
# ['Plate (page 63) from CIRQUE', 'Fernand Léger', 'French', 1881, 1955, 'Male', 1950, 'Prints & Illustrated Books']
# ['Untitled', 'David Moreno', 'American', 1957, '', 'Male', 2001, 'Drawings']
# ['Solo for Violin', 'George Maciunas', 'American', 1931, 1978, 'Male', 1962, 'Prints & Illustrated Books']
# ['Untitled (White Circle Collage)', 'Yutaka Matsuzawa', 'Japanese', 1922, 2006, 'Male', 1967, 'Prints & Illustrated Books']
# ['Installation View', 'Hayley Tompkins', 'Scottish', 1971, '', 'Female', 2003, 'Drawings']
# ['Casa La Villa, La Dehesa, Chile', 'Juan Baixas', 'Chilean', 1942, '', 'Male', 1980, 'Architecture & Design']
# ['Study of Perspective - Hong Kong', 'Ai Weiwei', 'Chinese', 1957, '', 'Male', 1999, 'Photography']
# ['Sainte Sébastienne', 'Louise Bourgeois', 'American', 1911, 2010, 'Female', 1993, 'Prints & Illustrated Books']
# ['Bowl', 'James Prestini', 'American', 1908, 1993, 'Male', 1945, 'Architecture & Design']
# ['Abstraction #4', 'Lotte Jacobi', 'American', 1896, 1990, 'Female', 1946, 'Photography']
# ['Female Torso I', 'William Brice', 'American', 1921, 2008, 'Male', 1962, 'Prints & Illustrated Books']
# ['Beep, Beep', 'Chuck Jones', 'American', 1912, 2002, 'Male', 1952, 'Film']
# ['Trois Bagatelles, Paralelle Aufführungen Neuster Musik, Kunsthandel Monet, Amsterdam, October 5, 1962', 'György Sándor Ligeti', 'Austrian', 1923, 2006, 'Male', 1962, 'Prints & Illustrated Books']
# ['Interior with Figures', 'Max Weber', 'American', 1881, 1961, 'Male', 1918, 'Drawings']
# ['Plate 11 (folio 25) from IL', 'Wessel Couzijn', 'Dutch', 1912, 1984, 'Male', 1966, 'Prints & Illustrated Books']
# ['Birth of Birds', 'André Masson', 'French', 1896, 1987, 'Male', 1925, 'Drawings']
# ['Untitled', 'Sigmar Polke', 'German', 1941, 2010, 'Male', 1973, 'Photography']
# ["Plate (page 29) from L'ÉVANGILE", 'Léo Marchutz', 'French', 1903, 1976, 'Male', 1948, 'Prints & Illustrated Books']
# ['Plate (page 126) from TABLEAU DE LA BOXE', 'André Dunoyer de Segonzac', 'French', 1884, 1974, 'Male', 1922, 'Prints & Illustrated Books']
# ['Laments (I Want to Live...)', 'Jenny Holzer', 'American', 1950, '', 'Female', 1989, 'Painting & Sculpture']
# ['Jarabina', 'Josef Koudelka', 'Czech', 1938, '', 'Male', 1963, 'Photography']
# ['Postal Dossier (Dossier postale)', 'Alighiero Boetti', 'Italian', 1940, 1994, 'Male', 1970, 'Prints & Illustrated Books']
# ['Caravan', 'Günter Haese', 'German', 1924, '', 'Male', 1965, 'Painting & Sculpture']
# ['THE MOINEAU WOMAN, plate LII (facing page 174) from LES ÂMES MORTES', 'Marc Chagall', 'French', 1887, 1985, 'Male', 1936, 'Prints & Illustrated Books']
# ['Vote McGovern', 'Andy Warhol', 'American', 1928, 1987, 'Male', 1972, 'Prints & Illustrated Books']
# ['Untitled, plate 10 of 11, from the illustrated book, He Disappeared into Complete Silence, second edition', 'Louise Bourgeois', 'American', 1911, 2010, 'Female', 1995, 'Prints & Illustrated Books']
# ['Student Series: École des Beaux-Arts de Bordeaux, or considerations towards a typology of disapearance', 'Ben Kinmont', 'American', 1963, '', 'Male', 2008, 'Prints & Illustrated Books']
# ['Right Eye', 'Aenne Biermann', 'German', 1898, 1933, 'Female', 1929, 'Photography']
# ['Landscape Panoramas', 'Jan Dibbets', 'Dutch', 1941, '', 'Male', 1971, 'Photography']
# ['Harold Kaye stationery', 'Elaine Lustig Cohen', 'American', 1927, 2016, 'Female', 1960, 'Architecture & Design']
# ["Beauvais, rue de l'Abbé Gelée", 'Eugène Atget', 'French', 1857, 1927, 'Male', 1904, 'Photography']
# ["It's late and the wind carries a faint sound as it moves through the trees. It could be anything. The jingling of little bells perhaps, or the tiny flickering out of tiny lives. I stroll down the sidewalk and close my eyes and open them and wait for my, mind to go perfectly blank. Like a room no one has ever entered, a room without any doors or windows. A place where nothing happens.", 'Ugo Rondinone', 'Swiss', 1964, '', 'Male', 2000, 'Media and Performance Art']
# ['Untitled. (portrait of German Dissenter?, pronounced halftone)', 'Michael Schmidt', 'German', 1945, 2014, 'Male', 1992, 'Photography']
# ['Plate XVI (folio 22) from BING', 'Georg Baselitz', 'German', 1938, '', 'Male', 1991, 'Prints & Illustrated Books']
# ['Yellow Wheel with Orange Border', 'Lawrence Weiner', 'American', 1942, '', 'Male', 1963, 'Painting & Sculpture']
# ['Riding Path (Reiterweg) (plate, folio 24) from Klänge (Sounds)', 'Vasily Kandinsky', 'French', 1866, 1944, 'Male', 1913, 'Prints & Illustrated Books']
# ['At Curragh Racecourse, near Dublin, Ireland', 'Henri Cartier-Bresson', 'French', 1908, 2004, 'Male', 1952, 'Photography']
# ['Distant View of Mont Serbal', 'Francis Frith', 'British', 1822, 1898, 'Male', 1876, 'Photography']
# ['Untitled', 'Laura Owens', 'American', 1970, '', 'Female', 2003, 'Drawings']
# ['Untitled', 'George Hoyningen-Huene', 'American', 1900, 1968, 'Male', 1937, 'Photography']
# ['Poster of the French National Railroad', 'Album-miscellaneous', 'Various', '', '', 'Gender Unknown/Other', 1922, 'Architecture & Design']
# ['Untitled', 'Jules Olitski', 'American', 1922, 2007, 'Male', 1957, 'Prints & Illustrated Books']
# ['Two Figures, Seated', 'Pablo Picasso', 'Spanish', 1881, 1973, 'Male', 1920, 'Prints & Illustrated Books']
# ['Pitcher', 'George Ohr', 'American', 1857, 1918, 'Male', 1900, 'Architecture & Design']
# ['Studies for Variation No. 7: Full Moon', 'Richard Lippold', 'American', 1915, 2002, 'Male', 1950, 'Drawings']
# ['Landscape with Freight Wagons', 'Pavel Tchelitchew', 'American', 1898, 1957, 'Male', 1920, 'Drawings']
# ['Sketchbook', 'Paul Delvaux', 'Belgian', 1897, 1994, 'Male', 1942, 'Drawings']
# ['No More Games (Study #3)', 'Benny Andrews', 'American', 1930, 2006, 'Male', 1970, 'Drawings']
# ['Baritone [Heinrich Rehkämper]', 'August Sander', 'German', 1876, 1964, 'Male', 1925, 'Photography']
# ['Circus-The Caribbean Orange', 'Gordon Matta-Clark', 'American', 1943, 1978, 'Male', 1978, 'Photography']
# ['Woman in a Bathtub', 'Fernando Botero', 'Colombian', 1932, '', 'Male', 1974, 'Drawings']
# ['Tailpiece (page 34) from SAGESSE', 'Maurice Denis', 'French', 1870, 1943, 'Male', 1900, 'Prints & Illustrated Books']
# ['El Morocco', 'Garry Winogrand', 'American', 1928, 1984, 'Male', 1955, 'Photography']
# ['The Hansen Album', 'Unknown', 'Nationality Unknown', '', '', 'Gender Unknown/Other', 1860, 'Photography']
# ['The Hired Hand', 'Peter Fonda', 'American', 1940, '', 'Male', 1971, 'Film']
# ['THE LION AND THE DONKEY HUNTING (plate 26, 2nd supplementary suite) from FABLES', 'Marc Chagall', 'French', 1887, 1985, 'Male', 1940, 'Prints & Illustrated Books']
# ['Untitled', 'Unknown', 'Nationality Unknown', '', '', 'Gender Unknown/Other', 1960, 'Photography']
# ['Saint-Cloud', 'Eugène Atget', 'French', 1857, 1927, 'Male', 1923, 'Photography']
# ['Cheap Return Tickets from this Underground Station', 'E. McKnight Kauffer', 'American', 1890, 1954, 'Male', 1927, 'Architecture & Design']
# ['Book cover for "Mozart\'s Librettos" translated by Robert Pack and Marjorie Lelash', 'Elaine Lustig Cohen', 'American', 1927, 2016, 'Female', 1959, 'Architecture & Design']
# ['Talisman', 'Victor Brauner', 'Romanian', 1903, 1966, 'Male', 1943, 'Painting & Sculpture']
# ['Vermilion Flycatcher, Male', 'Eliot Porter', 'American', 1901, 1990, 'Male', 1941, 'Photography']
# ['Inflatable Armchair', 'Quasar (Nguyen Manh Khanh)', 'Vietnamese', 1934, '', 'Gender Unknown/Other', 1968, 'Architecture & Design']
# ['Duplicate of Coffee Mill (Etching) (1st supplementary suite, plate 11) from Du Cubisme', 'Marcel Duchamp', 'American', 1887, 1968, 'Male', 1947, 'Prints & Illustrated Books']
# ['zentrum', 'Dorit Margreiter', 'Austrian', 1967, '', 'Female', 2006, 'Media and Performance Art']
# ['Heurtoir, 43 rue Sainte-Anne', 'Eugène Atget', 'French', 1857, 1927, 'Male', 1904, 'Photography']
# ['Paris, France', 'Lee Friedlander', 'American', 1934, '', 'Male', 1972, 'Photography']
# ['Plate (page 187) from FLORILÈGE DES AMOURS', 'Henri Matisse', 'French', 1869, 1954, 'Male', 1944, 'Prints & Illustrated Books']
# ['In-text plate (page 26) from EL SOMBRERON', 'Alfredo Zalce', 'Mexican', 1908, 2003, 'Male', 1946, 'Prints & Illustrated Books']
# ['Untitled from Wandering Position', 'Yukinori Yanagi', 'Japanese', 1959, '', 'Male', 1997, 'Prints & Illustrated Books']
# ['In-text plate (page 273) from DAPHNIS ET CHLOÉ', 'Pierre Bonnard', 'French', 1867, 1947, 'Male', 1902, 'Prints & Illustrated Books']
# ['Boy with a Straw Hat Waiting to March in a Pro-War Parade, New York City', 'Diane Arbus', 'American', 1923, 1971, 'Female', 1967, 'Photography']
# ['Six Tenant Farmers Without Farms, Hardeman County, Texas', 'Dorothea Lange', 'American', 1895, 1965, 'Female', 1938, 'Photography']
# ['At the Hanneton (Au Hanneton)', 'Henri de Toulouse-Lautrec', 'French', 1864, 1901, 'Male', 1898, 'Prints & Illustrated Books']
# ['Untitled', 'Luigi Ghirri', 'Italian', 1943, 1992, 'Male', 1970, 'Photography']
# ['Built-in Cabinet for Record Player, Records, and Radio, Loudspeaker layout, Telefunken 1940', 'Lilly Reich', 'German', 1885, 1947, 'Female', 1940, 'Architecture & Design']
# ['Untitled (for Parkett no. 87)', 'Annette Kelm', 'German', 1975, '', 'Female', 2010, 'Prints & Illustrated Books']
# ['Winter Shell on Sale Till Next May', 'E. McKnight Kauffer', 'American', 1890, 1954, 'Male', 1920, 'Architecture & Design']
# ['Family Tree from The Hundred Videos', 'Steve Reinke', 'Canadian', 1963, '', 'Male', 1989, 'Media and Performance Art']
# ['Shades and Tints (Drapery fabric)', 'Emily Belding', 'American', 1904, 1999, 'Female', 1954, 'Architecture & Design']
# ['Poster of the French National Railroad', 'Album-miscellaneous', 'Various', '', '', 'Gender Unknown/Other', 1922, 'Architecture & Design']
# ['Spiral Woman, plate 2 of 7, from the portfolio, La Réparation', 'Louise Bourgeois', 'American', 1911, 2010, 'Female', 2001, 'Prints & Illustrated Books']
# ['The 1970 Miss General Idea Pageant', 'General Idea', 'Canadian', '', '', 'Male', 1971, 'Prints & Illustrated Books']
# ['Batucada (for Parkett no. 85)', 'Beatriz Milhazes', 'Brazilian', 1960, '', 'Female', 2009, 'Prints & Illustrated Books']
# ['3rd Element Black for VENTRILOQUIST', 'Jasper Johns', 'American', 1930, '', 'Male', 1986, 'Prints & Illustrated Books']
# ['Untitled (Leda)', 'Constantin Brancusi', 'French', 1876, 1957, 'Male', 1921, 'Photography']
# ['Continuous Instability--Light', 'Julio Le Parc', 'Argentine', 1928, '', 'Male', 1962, 'Painting & Sculpture']
# ['PÈRE UBU, CHANTER (plate, facing page 32) from RÉINCARNATIONS DU PÈRE UBU', 'Georges Rouault', 'French', 1871, 1958, 'Male', 1924, 'Prints & Illustrated Books']
# ['Plate (folio 29 verso) from LOS SIETE PECADOS CAPITALES', 'Leonel Gongora', 'Colombian', 1932, '', 'Male', 1986, 'Prints & Illustrated Books']
# ['Study for New Moon, New York', 'George Ault', 'American', 1891, 1948, 'Male', 1944, 'Drawings']
# ['Plate (folio 4 verso) from Boundayr', 'Sam Francis', 'American', 1923, 1994, 'Male', 1986, 'Prints & Illustrated Books']
# ['Walt Paul Store, WS, Prince', 'Paul McCarthy', 'American', 1945, '', 'Male', 2013, 'Prints & Illustrated Books']
# ['Three from Female Portraits', 'Carroll Dunham', 'American', 1949, '', 'Male', 2000, 'Prints & Illustrated Books']
# ['Tailpiece (page 8) from SAGESSE', 'Maurice Denis', 'French', 1870, 1943, 'Male', 1900, 'Prints & Illustrated Books']
# ['Salon de la Plume', 'Unknown', 'Nationality Unknown', '', '', 'Gender Unknown/Other', 1895, 'Architecture & Design']
# ['Farnsworth House, Plano, Illinois (Plan, sections)', 'Ludwig Mies van der Rohe', 'American', 1886, 1969, 'Male', 1948, 'Architecture & Design']
# ['Conversations before an Eviction', 'Fergus Bourke', 'Irish', 1934, 2004, 'Male', 1968, 'Photography']
# ['Red over Yellow (Rouge sur jaune) from Suite of Twenty-Seven Color Lithographs', 'Ellsworth Kelly', 'American', 1923, 2015, 'Male', 1964, 'Prints & Illustrated Books']
# ['Bed', 'Robert Rauschenberg', 'American', 1925, 2008, 'Male', 1955, 'Painting & Sculpture']
# ['Untitled, From Leonardo', 'Jean-Michel Basquiat', 'American', 1960, 1988, 'Male', 1983, 'Prints & Illustrated Books']
# ['New York', 'Helen Levitt', 'American', 1913, 2009, 'Female', 1938, 'Photography']
# ['In-text plate (folio 12) from POÉSIE ET VÉRITÉ 1942', 'Oscar Domínguez', 'French', 1906, 1957, 'Male', 1947, 'Prints & Illustrated Books']
# ['London', 'Garry Winogrand', 'American', 1928, 1984, 'Male', 1967, 'Photography']
# ['In-text plate (folio 18) from MECCANO', 'Enrico Baj', 'Italian', 1924, 2003, 'Male', 1966, 'Prints & Illustrated Books']
# ['Porters', 'August Sander', 'German', 1876, 1964, 'Male', 1929, 'Photography']
# ["Ambassade d'Autriche, 57 rue de Varenne", 'Eugène Atget', 'French', 1857, 1927, 'Male', 1905, 'Photography']
# ['Cantor Drive-in Restaurant, Indianapolis, IN, Restaurant Sign. "38 Way."  Perspective', 'Ludwig Mies van der Rohe', 'American', 1886, 1969, 'Male', 1946, 'Architecture & Design']
# ['Untitled (Edward and Clara Smith Steichen On Their Honeymoon)', 'Edward Steichen', 'American', 1879, 1973, 'Male', 1903, 'Photography']
# ['Untitled (Heat/Gun)', 'Marco Breuer', 'German', 1966, '', 'Male', 1999, 'Photography']
# ['Plate (folio 7) from EXPLORATIONS', 'Henri Goetz', 'French', 1909, 1989, 'Male', 1947, 'Prints & Illustrated Books']
# ['High Peak', 'Matthew Rackham Barnes', 'American', 1880, 1951, 'Male', 1936, 'Painting & Sculpture']
# ['Picasso Sculpture (paper, skull)', 'Brassaï (Gyula Halász)', 'French', 1899, 1984, 'Male', 1943, 'Photography']
# ['Oval with Points', 'Henry Moore', 'British', 1898, 1986, 'Male', 1968, 'Painting & Sculpture']
# ['Cementerio de la Ciudad Abierta, Ritoque, Chile', 'Juan Baixas', 'Chilean', 1942, '', 'Male', 1975, 'Architecture & Design']
# ['The Catboat', 'Edward Hopper', 'American', 1882, 1967, 'Male', 1922, 'Prints & Illustrated Books']
# ["Dognat' i peregnat' v tekhniko-ekonomicheskom otnoshenii peredovye kapitalisticheskie strany v 10 let. 70 kartinnye diagrammna otkrytkakh", 'Unknown', 'Nationality Unknown', '', '', 'Gender Unknown/Other', 1931, 'Prints & Illustrated Books']
# ['Plate (page 11) from The Dive', 'Alex Katz', 'American', 1927, '', 'Male', 2011, 'Prints & Illustrated Books']

# %%
from csv import reader

moma = list(reader(open("artworks_clean.csv", encoding = "utf-8")))
moma[0:3]
# Out:
# [['Title',
#   'Artist',
#   'Nationality',
#   'BeginDate',
#   'EndDate',
#   'Gender',
#   'Date',
#   'Department'],
#  ['Dress MacLeod from Tartan Sets',
#   'Sarah Charlesworth',
#   'American',
#   '1947',
#   '2013',
#   'Female',
#   '1986',
#   'Prints & Illustrated Books'],
#  ['Duplicate of plate from folio 11 verso (supplementary suite, plate 4) from ARDICIA',
#   'Pablo Palazuelo',
#   'Spanish',
#   '1916',
#   '2007',
#   'Male',
#   '1978',
#   'Prints & Illustrated Books']]
